# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wages_df = pd.read_csv('us_wage_data.csv')

# %%
wages_df
# Out:
#       Sex   Race and ethnicity  Median Earnings (USD)  \
# 0     Men                  All                61199.0
# 1   Women                  All                51216.0
# 2     Men                Asian                81833.0
# 3   Women                Asian                63753.0
# 4     Men                Black                50115.0
# ..    ...                  ...                    ...
# 75  Women                Black                37121.0
# 76    Men             Hispanic                41716.0
# 77  Women             Hispanic                31969.0
# 78    Men  White, not Hispanic                50581.0
# 79  Women  White, not Hispanic                36483.0
#
#                  Occupation Group
# 0                      All Groups
# 1                      All Groups
# 2                      All Groups
# 3                      All Groups
# 4                      All Groups
# ..                            ...
# 75  Production and transportation
# ...

# %%
df_pivot = pd.pivot_table(
	wages_df,
	values="Median Earnings (USD)",
	index="Race and ethnicity",
	columns="Occupation Group",
	aggfunc=np.mean
)
# Out:
# /tmp/ipykernel_1132/1557816408.py:1: FutureWarning: The provided callable <function mean at 0x7f78f804fa60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_pivot = pd.pivot_table(

# %%
f,ax=plt.subplots(figsize=(10,4))

df_pivot.plot(ax=ax,kind='bar',stacked=True)

f.suptitle('US Median Earnings by Race and Ethnicity')
# Out:
# Text(0.5, 0.98, 'US Median Earnings by Race and Ethnicity')

# %%
#wages_df.plot(kind='bar', x='Race and ethnicity', y='Median Earnings (USD)', stacked=True)
