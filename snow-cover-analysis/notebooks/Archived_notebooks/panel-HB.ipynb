# %%
#!pip install leafmap

# %%
#!pip install localtileserver

# %%
# !pip install nbextension
# Out:
# ERROR: Could not find a version that satisfies the requirement nbextension (from versions: none)
# ERROR: No matching distribution found for nbextension

# %%
!
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: contrib dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert nbextensions_configurator notebook run
# server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
#!pip -q install panel ipyleaflet ipywidgets_bokeh geopandas hvplot xarray_leaflet
import pandas as pd
import panel as pn
import holoviews as hv
import hvplot.pandas
import ipyleaflet
import geopandas as gpd
#import xarray_leaflet
from ipyleaflet import Map, CircleMarker, GeoJSON, LayerGroup, MarkerCluster, basemaps
from holoviews.streams import Stream, param
import json

import xarray as xr

from holoviews.streams import Stream, param
import folium
import folium.plugins
import matplotlib.pyplot as plt
import html
import random
import leafmap.foliumap as leafmap
import numpy as np
from param import Parameterized, String
hv.extension('bokeh', "plotly")
# Initialize Panel extension
#pn.extension('plotly', 'ipywidgets')
pn.extension('ipywidgets')
#pn.extension('mathjax')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# ...

# %%
#!pip -q install panel ipyleaflet ipywidgets_bokeh geopandas hvplot xarray_leaflet

import panel as pn
import holoviews as hv
import ipyleaflet
import geopandas as gpd
#import xarray_leaflet
from ipyleaflet import Map, CircleMarker, GeoJSON, LayerGroup, MarkerCluster
from holoviews.streams import Stream, param
import json
import pandas as pd
import xarray as xr
import panel as pn
import holoviews as hv
import ipyleaflet
import geopandas as gpd
from ipyleaflet import Map, GeoJSON
from holoviews.streams import Stream, param
import json
import folium
import folium.plugins
import matplotlib.pyplot as plt
# Initialize Panel extension
#pn.extension('plotly', 'ipywidgets')
#pn.extension('ipywidgets')
import os

from leafmap import leafmap
import numpy as np

import html
import leafmap.foliumap as leafmap

pn.extension("ipywidgets", "folium", sizing_mode="stretch_width")
# Out:
# WARNING:param.panel_extension: folium extension not recognized and will be skipped.
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = f"{os.environ['JUPYTERHUB_SERVICE_PREFIX']}/proxy/{{port}}"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = f"{os.environ['JUPYTERHUB_SERVICE_PREFIX']}/proxy/{{port}}"
#
# File ~/micromamba/envs/analysis_2023/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'JUPYTERHUB_SERVICE_PREFIX'

# %%
import os
os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = f"{os.environ['JUPYTERHUB_SERVICE_PREFIX'].lstrip('/')}/proxy/{{port}}"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = f"{os.environ['JUPYTERHUB_SERVICE_PREFIX'].lstrip('/')}/proxy/{{port}}"
#
# File ~/micromamba/envs/analysis_2023/lib/python3.9/os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'JUPYTERHUB_SERVICE_PREFIX'

# %%
huc2_gdf = gpd.read_file('../data/huc2.geojson')
huc10_gdf = gpd.read_file('../data/huc10_clusters_loc.geojson')
#huc10_gdf.geometry = huc10_gdf.simplify(tolerance=0.01, preserve_topology=True)

# %%
huc10_swe = pd.read_csv('../data/swe_totals_ucrb.csv')

# %%
huc10_swe = huc10_swe.rename(columns={'swe_snv_sum_m3':'Calculated SWE', 'swe_reanalysis_sum_m3':'Reanalysis SWE'})

# %%
huc10_swe['Calculated SWE (acre feet)'] = huc10_swe['Calculated SWE'] * 0.000810714
huc10_swe['Reanalysis SWE (acre feet)'] = huc10_swe['Reanalysis SWE'] * 0.000810714

# %%
huc2_14 = huc2_gdf[huc2_gdf['huc2']==14]

# %%
# swe_4326_ds = xr.open_dataset('../data/swe_reanalysis_ucrb.nc')['SWE_Post'].compute()#.rio.clip_box(miny=36,maxy=42,minx=-110,maxx=-100).compute() #.rio.reproject('EPSG:3857')
# swe_webmerc_ds = swe_4326_ds.rio.reproject('EPSG:3857').compute()

# %%
#xr.open_dataset('../data/swe_calculated_snv.nc')['SWE_Post'].spatial_ref.values#sel(Year=0).plot.imshow()

# %%
swe_reanalysis = xr.open_dataset('../data/SWE_reanalysis_32yrs.nc',mask_and_scale=True)['SWE_Post'].rio.clip_box(miny=36,maxy=42,minx=-110,maxx=-100).where(lambda x: x>0).compute() 
swe_calculated = xr.open_dataset('../data/swe_calculated_snv.nc',mask_and_scale=True)['SWE_Post'].rio.write_crs('EPSG:32611').rio.reproject_match(swe_reanalysis).compute()

# %%
f,ax=plt.subplots(1,2)
swe_reanalysis.sel(Year=1990).plot.imshow(ax=ax[0])
swe_calculated.sel(Year=0).plot.imshow(ax=ax[1])

# %%
swe_reanalysis.rio.crs

# %%
swe_calculated.rio.crs

# %%
huc10_gdf.geometry.centroid

# %%
huc10_swe

# %%
huc10_swe_subset = huc10_swe[huc10_swe['huc10_id']==1401000107]

# %%
huc10_swe['huc10_id'].dtype

# %%
huc10_swe[huc10_swe['huc10_id']==1401000107].loc[0,'name']

# %%
code = '1401000107'

# %%
int(code)

# %%
plot = huc10_swe[huc10_swe['huc10_id']==1401000107].hvplot.line(x='year', y=['Calculated SWE','Reanalysis SWE'], value_label='Total SWE in Watershed (m3)', title=f"{huc10_swe[huc10_swe['huc10_id']==1401000107].loc[0,'name']}")
plot.opts(legend_position='bottom', legend_cols=2)
#plot.get_dimension('variable').label=''
#labels = ['Calculated SWE', 'SWE Reanalysis'],

# %%
huc10_swe[huc10_swe['huc10_id']==int(code)]['name'][0]

# %%
huc2_gdf['huc2'] = huc2_gdf['huc2'].astype('int32')

# %%
huc2_gdf['huc2'].dtype

# %%
huc2_gdf

# %%
huc2_14.plot()

# %%
huc2_14.crs

# %%
huc2_14.to_crs('epsg:4326').geometry.centroid

# %%
# Load the GeoDataFrame
center = [39.16513, -109.02301]  # Adjust as needed
# Create the ipyleaflet map
def create_ipyleaflet_map():
    
    m = Map(center=center, zoom=6, scroll_wheel_zoom=True)

    # Add HUC2 GeoJSON layer
    huc10_layer = GeoJSON(
        data=json.loads(huc10_gdf.to_crs('EPSG:4326').to_json()),
        style={'color': 'black', 'weight': 2, 'fillColor': 'cornflowerblue', 'fillOpacity': 0.2},
        hover_style={'fillColor': 'midnightblue', 'fillOpacity': 0.2},
        name='HUC10' # check
    )
    huc2_layer = GeoJSON(
        data=json.loads(huc2_14.to_crs('EPSG:4326').to_json()),
        style={'color': 'black', 'weight': 3, 'fillColor': 'none'},
        name='HUC2' # check
    )

    # Add click event to GeoJSON layer
    def on_click(event, feature, **kwargs):
        properties = feature['properties']
        code = properties.get('huc10', 'Unknown')
        click_stream.event(code=code)
        print(f'HUC code clicked: {code}')  # Debugging statement

    huc10_layer.on_click(on_click)
    m.add_layer(huc2_layer)
    m.add_layer(huc10_layer)

    return m

def create_folium_map(year):
    m = folium.Map(location=center, zoom_start=5)

    layer_left = folium.TileLayer('openstreetmap')
    
    data_slice_1 = swe_reanalysis.sel(Year=year)
    
    bounds_1 = [[data_slice_1.y.min().item(), data_slice_1.x.min().item()],
              [data_slice_1.y.max().item(), data_slice_1.x.max().item()]]
    
    layer_left = folium.raster_layers.ImageOverlay(
        image=data_slice_1.to_numpy(),
        bounds=bounds_1,
        opacity=1,
        colormap=lambda x: (0,0,1,x))

    layer_left.add_to(m)
    
    
    
    layer_right = folium.TileLayer('openstreetmap')

    data_slice_2 = swe_calculated.sel(Year=year-1990)
    
    bounds_2 = [[data_slice_2.y.min().item(), data_slice_2.x.min().item()],
              [data_slice_2.y.max().item(), data_slice_2.x.max().item()]]
    
    layer_right = folium.raster_layers.ImageOverlay(
        image=data_slice_2.to_numpy(),
        bounds=bounds_2,
        opacity=1,
        colormap=lambda x: (0,0,1,x))
    
    
    layer_right.add_to(m)
    
    sbs = folium.plugins.SideBySideLayers(layer_left=layer_left, layer_right=layer_right)

    m.add_child(sbs)
    #sbs.add_to(m)
    

    

    
    return m


# Create the map
ipyleaflet_map = create_ipyleaflet_map()
# Define a stream to capture map clicks
class ClickStream(Stream):
    code = param.String(default='1401000107')

# Instantiate the click stream
click_stream = ClickStream()

# Create a plot that updates based on the click location using hvPlot

def create_plot(code):
    code = int(code)
    print(f'Code received in create_plot: {code}')  # Debugging statement
    plot = huc10_swe[huc10_swe['huc10_id']==code].hvplot.line(x='year', y=['Calculated SWE','Reanalysis SWE'], value_label='Total SWE in Watershed ($m^3$)', title=f"{huc10_swe[huc10_swe['huc10_id']==code].loc[0,'name']}") #hv.Text(0.5, 0.5, f'HUC Code: {code}', halign='center')
    plot.opts(legend_position='bottom', legend_cols=2)
    return plot

# Define a DynamicMap that updates based on the click stream
dynamic_map = hv.DynamicMap(lambda code: create_plot(code), streams=[click_stream.param.code])



# Convert ipyleaflet map to Panel

def update_folium_map(event):
    year = event.new
    new_folium_map = create_folium_map(year)
    folium_pane.object = new_folium_map._repr_html_()

folium_map = create_folium_map(1990)  # Start with the initial year
folium_pane = pn.pane.plot.Folium(folium_map) #, height=400, width=400


year_slider = pn.widgets.IntSlider(name='Year', format='0', start=1990, end=2021)
year_slider.param.watch(update_folium_map, 'value')



ipyleaflet_pane = pn.pane.IPyWidget(ipyleaflet_map) #, height=400, width=400

# Create the layout
#layout = pn.Row(ipyleaflet_pane, pn.panel(dynamic_map, height=400, width=400),folium_pane,year_slider)
gspec = pn.GridSpec(sizing_mode='stretch_both', max_height=800)

gspec[0, 0] = ipyleaflet_pane
gspec[0, 1] = folium_pane
gspec[1, 0:2] = pn.panel(dynamic_map)


# Define the Panel app
def panel_app():
    pn.state.add_periodic_callback(lambda: None, period=100, count=100)
    #return layout
    return gspec

# Start the server
pn.serve({'/': panel_app}, port=5225, show=True)

# %% [markdown]
# ### With Shahzaib's ChatGPT Changes:

# %%
import json
import hvplot.pandas
import panel as pn
import param
from param import Parameterized, String
from ipyleaflet import Map, GeoJSON
import geopandas as gpd
import folium
import xarray as xr
import hvplot.xarray
import holoviews as hv
import folium.plugins
import random

# %%
huc10_swe
# Out:
#         huc10_id  year  swe_snv_sum  swe_reanalysis_sum  snv_snotel  \
# 0     1401000107  1990   540.767822          390.051422    0.008432
# 1     1401000107  1991   629.325073          434.512390    0.325875
# 2     1401000107  1992   297.235443          442.974609   -0.864536
# 3     1401000107  1993   607.185730          711.315186    0.246514
# 4     1401000107  1994   381.364807          403.953003   -0.562965
# ...          ...   ...          ...                 ...         ...
# 9659  1404010610  2017     8.141639            7.115200    0.504671
# 9660  1404010610  2018     6.198155            0.412800    0.137638
# 9661  1404010610  2019     4.532314            9.636200   -0.176963
# 9662  1404010610  2020    18.414333            9.251200    2.444706
# 9663  1404010610  2021    10.085121            4.700800    0.871705
#
#                          name  Calculated SWE  Reanalysis SWE
# 0                 Muddy Creek    1.107896e+08    7.991161e+07
# ...

# %%
filtered_data = huc10_swe[huc10_swe['huc10_id'] == 1401000107]
plot = filtered_data.hvplot.line(x='year', y=['Calculated SWE (acre feet)', 'Reanalysis SWE (acre feet)'],
                                     value_label='Total SWE in Watershed \n (acre feet)',
                                     title=f"{filtered_data.iloc[0]['name']}")
plot.opts(legend_position='right', legend_cols=1)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (Total SWE in Watershed
#  (acre feet))

# %%
m = Map(basemap = basemaps.CartoDB.Positron, center=center, zoom=5, scroll_wheel_zoom=True)

# Add HUC2 GeoJSON layer
huc10_layer = GeoJSON(
    data=json.loads(huc10_gdf.to_crs('EPSG:4326').to_json()),
    style={'color': 'darkgrey', 'weight': 1, 'fillColor': 'cornflowerblue', 'fillOpacity': 0.3},
    hover_style={'fillColor': 'midnightblue', 'fillOpacity': 0.2},
    name='HUC10' # check
)
huc2_layer = GeoJSON(
    data=json.loads(huc2_14.to_crs('EPSG:4326').to_json()),
    style={'color': 'darkgrey', 'weight': 2, 'fillColor': 'none'},
    name='HUC2' # check
)
m.add_layer(huc2_layer)
m.add_layer(huc10_layer)
m
# Out:
# Map(center=[39.16513, -109.02301], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %% [markdown]
# """
#         ## Interactive Snow Analysis Dashboard
#         Explore snow water equivalent (SWE) data using a novel estimation method.
#         Snow is an important water resource in the Upper Colorado River Basin (UCRB). It delays the timing of runoff so that winter precipitation enters streams and reservoirs in the spring and summer, when demand for irrigation and drinking water is highest. Current-season estimates of snow water equivalent (SWE) - the amount of water stored in the snowpack - are critical to allocating water resources correctly. Current methods are unable to accurately estimate current-year SWE, so water managers need new tools.
#
#         Here we present a novel method to estimate current-year SWE.
#         """

# %% [markdown]
# $Standard Normal Variate = SWE{current year} - Mean{30-year} / Standard Deviation{30-year}$

# %%
# Create the ipyleaflet map
center = [39.16513, -109.02301]
def create_ipyleaflet_map():
    m = Map(basemap = basemaps.CartoDB.Positron, center=center, zoom=5, scroll_wheel_zoom=True)

    # Add HUC2 GeoJSON layer
    huc10_layer = GeoJSON(
        data=json.loads(huc10_gdf.to_crs('EPSG:4326').to_json()),
        style={'color': 'darkgrey', 'weight': 1, 'fillColor': 'cornflowerblue', 'fillOpacity': 0.3},
        hover_style={'fillColor': 'midnightblue', 'fillOpacity': 0.2},
        name='HUC10' # check
    )
    huc2_layer = GeoJSON(
        data=json.loads(huc2_14.to_crs('EPSG:4326').to_json()),
        style={'color': 'darkgrey', 'weight': 2, 'fillColor': 'none'},
        name='HUC2' # check
    )

    # Add click event to GeoJSON layer
    def on_click(event, feature, **kwargs):
        properties = feature['properties']
        code = properties.get('huc10', 'Unknown')
        click_stream.code = code
        click_stream.param.trigger('code')
        print(f'HUC code clicked: {code}')  # Debugging statement

    huc10_layer.on_click(on_click)
    m.add_layer(huc2_layer)
    m.add_layer(huc10_layer)

    return m

def create_folium_map(year):
    m = folium.Map(location=center, zoom_start=5)

    layer_left = folium.TileLayer('openstreetmap')
    
    data_slice_1 = swe_reanalysis.sel(Year=year)
    
    bounds_1 = [[data_slice_1.y.min().item(), data_slice_1.x.min().item()],
              [data_slice_1.y.max().item(), data_slice_1.x.max().item()]]
    
    layer_left = folium.raster_layers.ImageOverlay(
        image=data_slice_1.to_numpy(),
        bounds=bounds_1,
        opacity=1,
        colormap=lambda x: (0,0,1,x))

    layer_left.add_to(m)
    
    layer_right = folium.TileLayer('openstreetmap')

    data_slice_2 = swe_calculated.sel(Year=year-1990)
    
    bounds_2 = [[data_slice_2.y.min().item(), data_slice_2.x.min().item()],
              [data_slice_2.y.max().item(), data_slice_2.x.max().item()]]
    
    layer_right = folium.raster_layers.ImageOverlay(
        image=data_slice_2.to_numpy(),
        bounds=bounds_2,
        opacity=1,
        colormap=lambda x: (0,0,1,x))
    
    layer_right.add_to(m)
    
    sbs = folium.plugins.SideBySideLayers(layer_left=layer_left, layer_right=layer_right)

    m.add_child(sbs)
       
    return m

# Create the map
ipyleaflet_map = create_ipyleaflet_map()

# Define a stream to capture map clicks
class ClickStream(Parameterized):
    code = String(default='1401000107')

# Instantiate the click stream
click_stream = ClickStream()

# Create a plot that updates based on the click location using hvPlot
def create_plot(code):
    code = int(code)
    print(f'Code received in create_plot: {code}')  # Debugging statement
    filtered_data = huc10_swe[huc10_swe['huc10_id'] == code]
    if filtered_data.empty:
        return hv.Text(0.5, 0.5, f'No data for HUC Code: {code}', halign='center')
    plot = filtered_data.hvplot.line(x='year', y=['Calculated SWE (acre feet)', 'Reanalysis SWE (acre feet)'],
                                     value_label='Total SWE in Watershed \n (acre feet)',
                                     title=f"{filtered_data.iloc[0]['name']}")
    plot.opts(legend_position='bottom', legend_cols=2)
    return plot

# Define a DynamicMap that updates based on the click stream
dynamic_map = hv.DynamicMap(lambda code: create_plot(code), streams=[click_stream.param.code])

# Convert ipyleaflet map to Panel
def update_folium_map(event):
    year = event.new
    new_folium_map = create_folium_map(year)
    folium_pane.object = new_folium_map._repr_html_()

folium_map = create_folium_map(1990)  # Start with the initial year
folium_pane = pn.pane.plot.Folium(folium_map,height=350,sizing_mode='stretch_width') #, height=400, width=400
 
year_slider = pn.widgets.IntSlider(name='Year', format='0', start=1990, end=2021)
year_slider.param.watch(update_folium_map, 'value')

ipyleaflet_pane = pn.pane.IPyWidget(ipyleaflet_map) #, height=400, width=400


# text = """
# Use the maps to explore snow water equivalent (SWE) patterns in the Upper Colorado River Basin (UCRB).
# """


# # Create the layout
# gspec = pn.GridSpec(sizing_mode='stretch_both') #, max_height=800

# gspec[0, 0:2] = pn.Column('# Snow Cover Analysis', pn.layout.Divider(), text, styles=dict(background='white'))
# gspec[1:2, 0] = ipyleaflet_pane
# gspec[1:2, 1] = folium_pane
# gspec[3:4, 0:2] = pn.panel(dynamic_map) #, height=400, width=400

# # Define the Panel app
# def panel_app():
#     pn.state.add_periodic_callback(lambda: None, period=100, count=100)
#     return gspec

# Create the layout

text = """
## Interactive Snow Dashboard: Explore snow water equivalent (SWE) data using a new estimation method!
          
To use the dashboard, select a HUC10 watershed within the UCRB in the left panel. When hovering over a HUC10 watershed, the name and HUC code of the watershed will appear. This feature can be useful if the user has a specific watershed of interest in mind. Once the watershed is selected, the Reanalysis and Calculated SWE gridded data will populate the right panel, and a timeseries of total watershed SWE on April 1 will populate the bottom panel. Water managers can hover over the bottom plot to see exactly how much SWE (in acre-feet) were calculated in each watershed using our method vs. the Reanalysis dataset. The calculated dataset will be extended to 2024 soon, to provide current-year April 1 SWE. These panel choices allow users to analyze both SWE products both temporally and spatially. Features like the ability to focus the range of the timeseries and zoom on the map, allow users to closer investigate years of interest.
        """
text2 = """
## More Information:  
In the Upper Colorado River Basin (UCRB), 74% of runoff comes from snowmelt (Li et al., 2017). Water managers would benefit from high-resolution, distributed snow water equivalent (SWE) estimates in real-time to predict streamflow and manage reservoirs. However, limited observations along with the spatial and temporal variability of mountain SWE make current methods inadequate to fully resolve SWE across the Western U.S. For example, real-time point measurements provide valuable information to water managers, but do not represent SWE values beyond a small radius due to the variability of snow across the landscape (Meromy et al., 2013; Molotch & Bales, 2005; Rice and Bales, 2010). Furthermore, distributed high-resolution model and remote sensing products are often retrospective instead of real-time.  

Here we present a new SWE dataset that can provide real-time SWE totals to water managers in the UCRB. We use real-time point measurements with historical distributed SWE patterns to calculate distributed real-time SWE.  

"""

gspec = pn.GridSpec(sizing_mode='stretch_both') #, max_height=800

gspec[0:1, 0:2] = pn.Column('# Snow Cover Analysis &#10052; &#10052; &#10052;', pn.layout.Divider(), styles=dict(background='cornflowerblue'))
gspec[1:2, 0:2] = pn.Column(text, pn.layout.Divider(), styles=dict(background='white'))
gspec[3:5, 0] = pn.Column(ipyleaflet_pane, margin=(0,0,10,0))
gspec[3:5, 1] = pn.Column(folium_pane, margin=(0,0,10,0))
gspec[6,1:2] = pn.Column(year_slider, height=50,margin=(0,0,-55,0))
gspec[6:7, 0:1] = pn.Column(pn.panel(dynamic_map,min_height=300,sizing_mode='stretch_both',margin=(0,0,-95,0)))
gspec[8:9,0:2] = pn.Column(pn.layout.Divider(), text2, styles=dict(background='white'))

# Define the Panel app
def panel_app():
    pn.state.add_periodic_callback(lambda: None, period=100, count=100)
    return gspec
# layout = pn.Row(ipyleaflet_pane, pn.panel(dynamic_map, height=400, width=400),folium_pane,year_slider)
# Create a custom template

# Add the layout to the template
#template.main.append(layout)

# Define the Panel app
# def panel_app():
#     return layout

# Start the server
rand_port = 5200+random.randint(1, 299)
pn.serve({'/': panel_app}, port=rand_port, show=True)
# Out:
# Launching server at http://localhost:5298
# Code received in create_plot: 1401000107
# Code received in create_plot: 1405000602
# Code received in create_plot: 1405000602
# HUC code clicked: 1405000602
# Code received in create_plot: 1405000601
# Code received in create_plot: 1405000601
# HUC code clicked: 1405000601
# Code received in create_plot: 1405000601
# HUC code clicked: 1405000601

# %%
text = """
        ## Interactive Snow Dashboard: Explore snow water equivalent (SWE) data using a new estimation method!
          
        In the Upper Colorado River Basin (UCRB), 74% of runoff comes from snowmelt (Li et al., 2017). Water managers would benefit from high-resolution, distributed snow water equivalent (SWE) estimates in real-time to predict streamflow and manage reservoirs. However, limited observations along with the spatial and temporal variability of mountain SWE make current methods inadequate to fully resolve SWE across the Western U.S. For example, real-time point measurements provide valuable information to water managers, but do not represent SWE values beyond a small radius due to the variability of snow across the landscape (Meromy et al., 2013; Molotch & Bales, 2005; Rice and Bales, 2010). Furthermore, distributed high-resolution model and remote sensing products are often retrospective instead of real-time.  

        Here we present a new SWE dataset that can provide real-time SWE totals to water managers in the UCRB. We use real-time point measurements with historical distributed SWE patterns to calculate distributed real-time SWE.
        
        To use the dashboard, select a HUC10 watershed within the UCRB in the left panel. The Reanalysis and Calculated SWE gridded data will populate the right panel, and a timeseries of total watershed SWE on April 1 will populate the bottom panel. Water managers can hover over the bottom plot to see exactly how much SWE (in acre-feet) were calculated in each watershed using our method vs. the Reanalysis dataset. The calculated datset will be extended to 2024 soon, to provide current-year April 1 SWE. 
        """

# %% [markdown]
# Water managers currently rely on point measurements (from the SNOTEL network) of SWE that are sparsely located throughout the UCRB, but the spatial variability of SWE makes point measurements inadequate representations of distributed SWE. Current methods can back-calculate distributed SWE once snow melts (called SWE Reanalysis), but are unable to accurately estimate current SWE. Water managers need new tools and datasets to calculate the total amount of SWE in each watershed before melt-out.
#
#         Here we present a novel method to estimate current-year SWE using historic SWE patterns and statistics. In previous work, we showed that the standard normal variates (Eq 1) are consistent within large regions. We calculated standard normal variates for April 1st SWE, and clustered to find regions in the UCRB that have similar standard normal variates. Using 30 years of SWE Reanalysis data, we calculate the 30-year mean and standard deviation of SWE at each Reanalysis grid cell. Then we use a nearby point measurement (from SNOTEL) of the current-year standard normal variate. We can rearrange Eq 1 so that we can calculate SWE at any gridcell. Then we can calculate the total SWE within each HUC10 watershed. (HUC10 watersheds are a certain sized watershed delineated by the U.S. Geological Survey.)
#
#         Equation 1.    $$ Standard Normal Variate = \frac{SWE_{current year} - Mean_{30-year}}{Standard Deviation_{30-year}} $$
#         Equation 2. $$ SWE_{current year} = Standard Normal Variate_{current year} * Standard Deviation_{30-year} + Mean_{30-year} $$

# %% [markdown]
# ### With Eric's Changes:

# %%
from param import Parameterized, String

# %%
# Create the ipyleaflet map
center = [39.16513, -109.02301]

def create_ipyleaflet_map():
    m = Map(center=center, zoom=5, scroll_wheel_zoom=True)

    # Add HUC2 GeoJSON layer
    huc10_layer = GeoJSON(
        data=json.loads(huc10_gdf.to_crs('EPSG:4326').to_json()),
        style={'color': 'black', 'weight': 2, 'fillColor': 'cornflowerblue', 'fillOpacity': 0.2},
        hover_style={'fillColor': 'midnightblue', 'fillOpacity': 0.2},
        name='HUC10' # check
    )
    huc2_layer = GeoJSON(
        data=json.loads(huc2_14.to_crs('EPSG:4326').to_json()),
        style={'color': 'black', 'weight': 3, 'fillColor': 'none'},
        name='HUC2' # check
    )

    # Add click event to GeoJSON layer
    def on_click(event, feature, **kwargs):
        properties = feature['properties']
        code = properties.get('huc10', 'Unknown')
        click_stream.code = code
        click_stream.param.trigger('code')
        center = [huc10_gdf[huc10_gdf['huc10'] == code].geometry.centroid.y.values[0], huc10_gdf[huc10_gdf['huc10'] == code].geometry.centroid.x.values[0]]
        update_folium_map()
        print(f'HUC code clicked: {code}')  # Debugging statement

    huc10_layer.on_click(on_click)
    m.add_layer(huc2_layer)
    m.add_layer(huc10_layer)

    return m

def create_folium_map(year,code=None):
    m = leafmap.Map(center=center,zoom=6)
    m.split_map(left_layer=swe_reanalysis.sel(Year=1990), left_args={'vmin':0,'vmax':1,'cmap':'Blues','nodata':np.nan}, right_layer=swe_calculated.sel(Year=0),right_args={'vmin':0,'vmax':1,'cmap':'Blues','nodata':np.nan})
    
    if code:
        m.add_gdf(huc10_gdf[huc10_gdf['huc10'] == code], layer_name='HUC10',zoom_to_layer=True, style={'color': 'black', 'weight': 2,'fillColor': 'blue', 'fillOpacity': 0.0},info_mode=None)
        #huc10_gdf[huc10_gdf['huc10'] == code].boundary.plot(color='black',linewidth=2)
        
    return m

# Create the map
ipyleaflet_map = create_ipyleaflet_map()

# Define a stream to capture map clicks
class ClickStream(Parameterized):
    code = String(default='1401000107')

# Instantiate the click stream
click_stream = ClickStream()

# Create a plot that updates based on the click location using hvPlot
def create_plot(code):
    code = int(code)
    print(f'Code received in create_plot: {code}')  # Debugging statement
    filtered_data = huc10_swe[huc10_swe['huc10_id'] == code]
    if filtered_data.empty:
        return hv.Text(0.5, 0.5, f'No data for HUC Code: {code}', halign='center')
    plot = filtered_data.hvplot.line(x='year', y=['Calculated SWE', 'Reanalysis SWE'],
                                     value_label='Total SWE in Watershed ($m^3$)',
                                     title=f"{filtered_data.iloc[0]['name']}")
    plot.opts(legend_position='bottom', legend_cols=2)
    return plot

# Define a DynamicMap that updates based on the click stream
dynamic_map = hv.DynamicMap(lambda code: create_plot(code), streams=[click_stream.param.code])

# Convert ipyleaflet map to Panel
def update_folium_map(event = None):
    if event:
        year = event.new
    else:
        year = year_slider.value
    new_folium_map = create_folium_map(year,code=click_stream.code)
    new_escaped_html = html.escape(new_folium_map.to_html())
    new_iframe_html = f'<iframe srcdoc="{new_escaped_html}" style="height:100%; width:100%" frameborder="0"></iframe>'
    folium_pane.object = new_iframe_html


folium_map = create_folium_map(1990)  # Start with the initial year
#folium_pane = pn.pane.plot.HTML(html.escape(folium_map.to_html()), height=400, width=400)
escaped_html = html.escape(folium_map.to_html())

# Create iframe embedding the escaped HTML and display it
iframe_html = f'<iframe srcdoc="{escaped_html}" style="height:100%; width:100%" frameborder="0"></iframe>'

# Display iframe in a Panel HTML pane
folium_pane = pn.pane.HTML(iframe_html, height=350, sizing_mode="stretch_width")

year_slider = pn.widgets.IntSlider(name='Year', format='0', start=1990, end=2021)
year_slider.param.watch(update_folium_map, 'value')



ipyleaflet_pane = pn.pane.IPyWidget(ipyleaflet_map) #, height=400, width=400



text = """
Use the maps to explore snow water equivalent (SWE) patterns in the Upper Colorado River Basin (UCRB).
"""


# Create the layout
gspec = pn.GridSpec(sizing_mode='stretch_both') #, max_height=800

gspec[0, 0:2] = pn.Column('# Snow Cover Analysis', pn.layout.Divider(), text, styles=dict(background='white'))
gspec[1:2, 0] = ipyleaflet_pane
gspec[1:2, 1] = folium_pane
gspec[3:4, 0:2] = pn.panel(dynamic_map) #, height=400, width=400

# Define the Panel app
def panel_app():
    pn.state.add_periodic_callback(lambda: None, period=100, count=100)
    return gspec

# Start the server
rand_port = 5200+random.randint(1, 299)
pn.serve({'/': panel_app}, port=rand_port, show=True)

# %%
# Create the ipyleaflet map
def create_ipyleaflet_map():
    
    m = Map(center=center, zoom=6, scroll_wheel_zoom=True)

    # Add HUC2 GeoJSON layer
    huc10_layer = GeoJSON(
        data=json.loads(huc10_gdf.to_crs('EPSG:4326').to_json()),
        style={'color': 'black', 'weight': 2, 'fillColor': 'blue', 'fillOpacity': 0.1},
        hover_style={'fillColor': 'red', 'fillOpacity': 0.2},
        name='HUC10' # check
    )

    # Add click event to GeoJSON layer
    def on_click(event, feature, **kwargs):
        properties = feature['properties']
        code = properties.get('huc10', 'Unknown')
        click_stream.event(code=code)
        center = [huc10_gdf[huc10_gdf['huc10'] == code].geometry.centroid.y.values[0], huc10_gdf[huc10_gdf['huc10'] == code].geometry.centroid.x.values[0]]
        update_folium_map()
        print(f'HUC code clicked: {code}')  # Debugging statement

    huc10_layer.on_click(on_click)
    m.add_layer(huc10_layer)

    return m

def create_folium_map(year,code=None):
    m = leafmap.Map(center=center,zoom=6)
    m.split_map(left_layer=swe_reanalysis.sel(Year=1990), left_args={'vmin':0,'vmax':1,'cmap':'Blues','nodata':np.nan}, right_layer=swe_calculated.sel(Year=0),right_args={'vmin':0,'vmax':1,'cmap':'Blues','nodata':np.nan})
    
    if code:
        m.add_gdf(huc10_gdf[huc10_gdf['huc10'] == code], layer_name='HUC10',zoom_to_layer=True, style={'color': 'black', 'weight': 2,'fillColor': 'blue', 'fillOpacity': 0.0},info_mode=None)
        #huc10_gdf[huc10_gdf['huc10'] == code].boundary.plot(color='black',linewidth=2)
        
    return m


# Create the map
ipyleaflet_map = create_ipyleaflet_map()
# Define a stream to capture map clicks
class ClickStream(Stream):
    code = param.String(default='')

# Instantiate the click stream
click_stream = ClickStream()

# Create a plot that updates based on the click location using hvPlot
def create_plot(code):
    print(f'Code received in create_plot: {code}')  # Debugging statement
    plot = hv.Text(0.5, 0.5, f'HUC Code: {code}', halign='center')
    return plot

# Define a DynamicMap that updates based on the click stream
dynamic_map = hv.DynamicMap(lambda code: create_plot(code), streams=[click_stream])



# Convert ipyleaflet map to Panel

def update_folium_map(event=None):
    if event:
        year = event.new
    else:
        year = year_slider.value
    new_folium_map = create_folium_map(year,code=click_stream.code)
    new_escaped_html = html.escape(new_folium_map.to_html())
    new_iframe_html = f'<iframe srcdoc="{new_escaped_html}" style="height:100%; width:100%" frameborder="0"></iframe>'
    folium_pane.object = new_iframe_html

folium_map = create_folium_map(1990)  # Start with the initial year
#folium_pane = pn.pane.plot.HTML(html.escape(folium_map.to_html()), height=400, width=400)
escaped_html = html.escape(folium_map.to_html())

# Create iframe embedding the escaped HTML and display it
iframe_html = f'<iframe srcdoc="{escaped_html}" style="height:100%; width:100%" frameborder="0"></iframe>'

# Display iframe in a Panel HTML pane
folium_pane = pn.pane.HTML(iframe_html, height=350, sizing_mode="stretch_width")

year_slider = pn.widgets.IntSlider(name='Year', format='0', start=1990, end=2021)
year_slider.param.watch(update_folium_map, 'value')



ipyleaflet_pane = pn.pane.IPyWidget(ipyleaflet_map, height=400, width=400)

# Create the layout
layout = pn.Row(ipyleaflet_pane, pn.panel(dynamic_map, height=400, width=400),folium_pane,year_slider)


# Define the Panel app
def panel_app():
    #pn.state.add_periodic_callback(lambda: None, period=100, count=100)
    return layout

# Start the server
pn.serve({'/': panel_app}, port=5225, show=True)

# %%
layout.save('index.html', embed=True)

# %%
year = 1990

# %%
m = folium.Map(location=center, zoom_start=5)

layer_left = folium.TileLayer('openstreetmap')

data_slice_1 = swe_reanalysis.sel(Year=year)

bounds_1 = [[data_slice_1.y.min().item(), data_slice_1.x.min().item()],
            [data_slice_1.y.max().item(), data_slice_1.x.max().item()]]

layer_left = folium.raster_layers.ImageOverlay(
    image=data_slice_1.to_numpy(),
    bounds=bounds_1,
    opacity=1,
    colormap=lambda x: (0,0,1,x))

layer_left.add_to(m)



layer_right = folium.TileLayer('openstreetmap')

data_slice_2 = swe_calculated.sel(Year=year-1990)

bounds_2 = [[data_slice_2.y.min().item(), data_slice_2.x.min().item()],
            [data_slice_2.y.max().item(), data_slice_2.x.max().item()]]

layer_right = folium.raster_layers.ImageOverlay(
    image=data_slice_2.to_numpy(),
    bounds=bounds_2,
    opacity=1,
    colormap=lambda x: (0,0,1,x))


layer_right.add_to(m)

sbs = folium.plugins.SideBySideLayers(layer_left=layer_left, layer_right=layer_right)

m.add_child(sbs)

m

# %%
# !pip install -q leafmap localtileserver
import leafmap.foliumap as leafmap

# %%
swe_webmerc_ds

# %%
#https://leafmap.org/notebooks/49_split_control/
#https://github.com/banesullivan/localtileserver
m = leafmap.Map(center=[37.6, -119], zoom=9)
m.split_map(
    swe_4326_ds.sel(Year=2015),
    swe_4326_ds.sel(Year=2020),
    left_args={"layer_name": "DEM", "colormap": "Blues","vmin":0,"vmax":1},
    right_args={"layer_name": "Classified DEM", "colormap": "Blues","vmin":0,"vmax":1},
)
m

# %%
m = folium.Map(location=center, zoom_start=4)
folium.TileLayer('https://gitlab.cs.washington.edu/cse512/24sp/fp/snow-cover-analysis/-/raw/master/data/SWE_reanalysis_32yrs.nc?ref_type=heads&inline=false',attr='Snow Cover').add_to(m)
m

# %%
import rioxarray as rxr
rxr.open_rasterio('/tmp/tmp1b1nkxgv.png').plot.imshow()

# %%
folium.TileLayer()

# %%
data_slice = swe_ds.sel(Year=2020)
data_slice

# %%
data_slice.y.min().item()

# %%
data_slice.to

# %%
swe_ds.leaflet.plot?

# %%
swe_ds.rio.crs

# %%
swe_ds.sel(Year=2000)['SWE_Post'].plot(vmin=0,vmax=5,cmap='Blues')
